# %% [markdown]
# **1.create a dataframe**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/2260131/3787929/admission_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230610%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230610T175418Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-045de7a2138d> in <cell line: 1>()
# ----> 1 df=pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/2260131/3787929/admission_data.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230610%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230610T175418Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
#       2 df
#
# ...

# %% [markdown]
#  **2.preprocessing**

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-633337079cd0> in <cell line: 1>()
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.size

# %%
df.info

# %%
df['Research'].unique()

# %%
df['Research'].nunique()

# %%
df.groupby('Research').size()

# %%
#4. Input-years of experience
    #Output-salary
x=df.iloc[:,6:7].values
x

# %%
y=df.iloc[:,7].values
y

# %%
#5. Train and Test variable
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)

# %%
#6.Normalization
#from sklearn.preprocessing import MinMaxScaler
#scaler=MinMaxScaler()
#x_train=scaler.fit_transform(x_train)
#x_test=scaler.fit_transform(x_test)

# %%
#7.Apply a classifier,regressor or clusteror
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
#8.Fit the model
model.fit(x_train,y_train)
#using the training variable we are training the model

# %%
#9.Predict the Output
y_pred=model.predict(x_test)
y_pred

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)*100
